# %%
from Mathematics_fundamentals.visualisations.visualisations import Visualisation
from Mathematics_fundamentals.functions.functions import Functions
from Mathematics_fundamentals.calculus.differentiation.differentiation import Differentiation

# %%
func = Functions()
vis = Visualisation()
diff = Differentiation()

# %% [markdown]
# ## Simple cubic plot, and finding the real root of it.

# %%
def cubic(x):
    return func.polynomial(x,1,0,8,-250)

axis = vis.make_axis()
vis.get_function_visualisation(cubic,-10,10,100,axis)
vis.show_visualisation()

# %%
diff.newton_raphson_method(cubic,5,verbose = True)
# Out:
# 'Iteration count: 4, root: (5.877,0.0024611329999686404)'

# %% [markdown]
# ### Circle tangent visualisation

# %%
def circle(x):
    return func.circle(x,3,1,1)

ax = vis.make_axis()
vis.visualise_conic_tangent(circle,3,-2,4,1000,ax)
vis.show_visualisation()
